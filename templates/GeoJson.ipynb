# %%
import pandas as pd
import pandas as pd
import os
import csv
import numpy as np
import json
from pandas.io.json import json_normalize
from pprint import pprint
from jsonmerge import merge

# %%
file = "../brewBuds_project2/static/Top100_zip.csv"
zip_codes = pd.read_csv(file)
zipcode = zip_codes["PostalCode"].tolist()
zipcodes = ' '.join(str(i) for i in zipcode)
print(zipcodes)
# Out:
# 20001 90045 22202 10014 10016 11201 20003 95035 10065 77056 98102 7310 11217 94105 60601 94596 75201 90403 10023 98115 10003 10005 95054 60610 77019 60607 20005 98121 94086 94109 94538 20852 2116 98033 50266 90069 94560 19103 20190 98208 30342 95131 90036 30305 60614 94123 90254 92117 92037 33606 94114 10010 93720 98052 92831 60661 60654 30307 19702 19106 27560 22201 60606 20016 20008 2139 91101 7030 75219 98011 95618 90292 20002 89139 96819 77008 10022 92123 2128 60611 98109 98133 92865 98272 33132 98007 96701 95687 15222 23233 98021 28273 75209 93036 94531 20010 76177 33301 99709 92626

# %%
dc_file = "../geojson/dc_district_of_columbia_zip_codes_geo.min.json"

with open(dc_file) as jsonfile:
    dc_json = json.load(jsonfile)

data = dc_json["features"]

dc_zips = []
# zipcodes = ['20001', '11201', '10014', '20002', '20003', '11217','94109','94086', '02139', '77008', '20010' ]

for i in range(len(data)):
    if data[i]["properties"]["ZCTA5CE10"] in zipcodes:
        dc_zips.append(data[i])

print(dc_zips)

with open('dc.json', 'w') as json_file:
  json.dump(dc_zips, json_file)
# Out:
# [{'type': 'Feature', 'properties': {'STATEFP10': '11', 'ZCTA5CE10': '20010', 'GEOID10': '1120010', 'CLASSFP10': 'B5', 'MTFCC10': 'G6350', 'FUNCSTAT10': 'S', 'ALAND10': 2807752, 'AWATER10': 16379, 'INTPTLAT10': '+38.9333665', 'INTPTLON10': '-077.0303116', 'PARTFLG10': 'N'}, 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[[-77.055403, 38.936371], [-77.05646, 38.936947], [-77.056345, 38.936919], [-77.05617, 38.936884], [-77.056062, 38.936866], [-77.055933, 38.936849], [-77.055756, 38.93684], [-77.055643, 38.93684], [-77.055498, 38.936843], [-77.055353, 38.936851], [-77.055075, 38.936869], [-77.054982, 38.936873], [-77.054935, 38.936876], [-77.054795, 38.936882], [-77.054655, 38.936886], [-77.054609, 38.936885], [-77.054516, 38.936877], [-77.054442, 38.936865], [-77.054275, 38.936817], [-77.054128, 38.936768], [-77.055403, 38.936371]]], [[[-77.018106, 38.928484], [-77.018129, 38.92849], [-77.018213, 38.928508], [-77.018241, 38.928513], [-77.018326, 38.928527], [-77.01843, 38.92854
# ...

# %%
ca_file = "../geojson/ca_california_zip_codes_geo.min.json"

with open(ca_file) as jsonfile:
    ca_json = json.load(jsonfile)

data = ca_json["features"]

ca_zips = []

for i in range(len(data)):
    if data[i]["properties"]["ZCTA5CE10"] in zipcodes:
        ca_zips.append(data[i])

print(ca_zips)
# with open('ca.json', 'w') as json_file:
#   json.dump(ca_zips, json_file)
# Out:
# [{'type': 'Feature', 'properties': {'STATEFP10': '06', 'ZCTA5CE10': '94560', 'GEOID10': '0694560', 'CLASSFP10': 'B5', 'MTFCC10': 'G6350', 'FUNCSTAT10': 'S', 'ALAND10': 35757865, 'AWATER10': 60530, 'INTPTLAT10': '+37.5041413', 'INTPTLON10': '-122.0323587', 'PARTFLG10': 'N'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[-122.054991, 37.549595], [-122.054412, 37.550029], [-122.053161, 37.550971], [-122.052671, 37.551326], [-122.052391, 37.55153], [-122.05208, 37.551742], [-122.051927, 37.55184], [-122.051242, 37.552296], [-122.051155, 37.552355], [-122.048677, 37.55388], [-122.048658, 37.553892], [-122.047806, 37.55438], [-122.047235, 37.554726], [-122.047212, 37.554741], [-122.046531, 37.555191], [-122.04559, 37.555867], [-122.045304, 37.556074], [-122.045052, 37.556261], [-122.044907, 37.55637], [-122.044633, 37.556579], [-122.044478, 37.556705], [-122.044338, 37.556821], [-122.044201, 37.556933], [-122.043955, 37.557139], [-122.043861, 37.557219], [-122.043387, 37.557639], [-122
# ...

# %%
ak_file = "../geojson/ak_alaska_zip_codes_geo.min.json"

with open(ca_file) as jsonfile:
    ak_json = json.load(jsonfile)

data = ak_json["features"]

ak_zips = []

for i in range(len(data)):
    if data[i]["properties"]["ZCTA5CE10"] in zipcodes:
        ak_zips.append(data[i])

print(ak_zips)
with open('ak.json', 'w') as json_file:
  json.dump(ak_zips, json_file)
# Out:
# [{'type': 'Feature', 'properties': {'STATEFP10': '06', 'ZCTA5CE10': '94560', 'GEOID10': '0694560', 'CLASSFP10': 'B5', 'MTFCC10': 'G6350', 'FUNCSTAT10': 'S', 'ALAND10': 35757865, 'AWATER10': 60530, 'INTPTLAT10': '+37.5041413', 'INTPTLON10': '-122.0323587', 'PARTFLG10': 'N'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[-122.054991, 37.549595], [-122.054412, 37.550029], [-122.053161, 37.550971], [-122.052671, 37.551326], [-122.052391, 37.55153], [-122.05208, 37.551742], [-122.051927, 37.55184], [-122.051242, 37.552296], [-122.051155, 37.552355], [-122.048677, 37.55388], [-122.048658, 37.553892], [-122.047806, 37.55438], [-122.047235, 37.554726], [-122.047212, 37.554741], [-122.046531, 37.555191], [-122.04559, 37.555867], [-122.045304, 37.556074], [-122.045052, 37.556261], [-122.044907, 37.55637], [-122.044633, 37.556579], [-122.044478, 37.556705], [-122.044338, 37.556821], [-122.044201, 37.556933], [-122.043955, 37.557139], [-122.043861, 37.557219], [-122.043387, 37.557639], [-122
# ...

# %%
ct_file = "../geojson/ct_connecticut_zip_codes_geo.min.json"

with open(ct_file) as jsonfile:
    ct_json = json.load(jsonfile)

data = ct_json["features"]

ct_zips = []

for i in range(len(data)):
    if data[i]["properties"]["ZCTA5CE10"] in zipcodes:
        ct_zips.append(data[i])

print(ct_zips)
with open('ct.json', 'w') as json_file:
  json.dump(ct_zips, json_file)
# Out:
# []

# %%
de_file = "../geojson/de_delaware_zip_codes_geo.min.json"

with open(de_file) as jsonfile:
    de_json = json.load(jsonfile)

data = de_json["features"]

de_zips = []

for i in range(len(data)):
    if data[i]["properties"]["ZCTA5CE10"] in zipcodes:
        de_zips.append(data[i])

print(de_zips)
with open('de.json', 'w') as json_file:
  json.dump(de_zips, json_file)
# Out:
# [{'type': 'Feature', 'properties': {'STATEFP10': '10', 'ZCTA5CE10': '19702', 'GEOID10': '1019702', 'CLASSFP10': 'B5', 'MTFCC10': 'G6350', 'FUNCSTAT10': 'S', 'ALAND10': 73325367, 'AWATER10': 637534, 'INTPTLAT10': '+39.6181998', 'INTPTLON10': '-075.7297243', 'PARTFLG10': 'N'}, 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[[-75.656156, 39.649816], [-75.656322, 39.649078], [-75.656445, 39.64853], [-75.657508, 39.648699], [-75.657781, 39.648762], [-75.657877, 39.648785], [-75.658088, 39.648826], [-75.658343, 39.64879], [-75.65861, 39.648746], [-75.658888, 39.648702], [-75.658934, 39.648826], [-75.659075, 39.649198], [-75.659122, 39.649322], [-75.658524, 39.649423], [-75.657317, 39.649628], [-75.656876, 39.649751], [-75.656749, 39.649796], [-75.656642, 39.649834], [-75.656432, 39.649864], [-75.656156, 39.649816]]], [[[-75.673968, 39.635488], [-75.674683, 39.635465], [-75.674836, 39.635481], [-75.674984, 39.635511], [-75.675127, 39.635556], [-75.675257, 39.635612], [-75.675379, 39.
# ...

# %%
fl_file = "../geojson/fl_florida_zip_codes_geo.min.json"

with open(fl_file) as jsonfile:
    fl_json = json.load(jsonfile)

data = fl_json["features"]

fl_zips = []

for i in range(len(data)):
    if data[i]["properties"]["ZCTA5CE10"] in zipcodes:
        fl_zips.append(data[i])

print(fl_zips)
with open('fl.json', 'w') as json_file:
  json.dump(fl_zips, json_file)
# Out:
# [{'type': 'Feature', 'properties': {'STATEFP10': '12', 'ZCTA5CE10': '33606', 'GEOID10': '1233606', 'CLASSFP10': 'B5', 'MTFCC10': 'G6350', 'FUNCSTAT10': 'S', 'ALAND10': 8501033, 'AWATER10': 2227222, 'INTPTLAT10': '+27.9174523', 'INTPTLON10': '-082.4522793', 'PARTFLG10': 'N'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[-82.463068, 27.91018], [-82.463091, 27.910291], [-82.462919, 27.91123], [-82.462748, 27.911412], [-82.463228, 27.911836], [-82.463399, 27.912564], [-82.463468, 27.913291], [-82.463434, 27.914321], [-82.463399, 27.915624], [-82.463399, 27.916805], [-82.463262, 27.917684], [-82.462851, 27.917896], [-82.463194, 27.918411], [-82.463399, 27.919017], [-82.463408, 27.919061], [-82.463571, 27.919835], [-82.463605, 27.920441], [-82.46357, 27.920684], [-82.464658, 27.921295], [-82.46461, 27.922378], [-82.4636, 27.935501], [-82.462657, 27.936282], [-82.463202, 27.936123], [-82.463929, 27.935842], [-82.464566, 27.9354], [-82.465203, 27.934878], [-82.465339, 27.933673], [-82.4
# ...

# %%
file = "../geojson/ga_georgia_zip_codes_geo.min.json"

with open(file) as jsonfile:
    state_json = json.load(jsonfile)

data = state_json["features"]

ga_zips = []

for i in range(len(data)):
    if data[i]["properties"]["ZCTA5CE10"] in zipcodes:
        ga_zips.append(data[i])

# print(zips)
# with open('ga.json', 'w') as json_file:
#   json.dump(zips, json_file)

# %%
file = "../geojson/hi_hawaii_zip_codes_geo.min.json"

with open(file) as jsonfile:
    state_json = json.load(jsonfile)

data = state_json["features"]

hi_zips = []

for i in range(len(data)):
    if data[i]["properties"]["ZCTA5CE10"] in zipcodes:
        hi_zips.append(data[i])

# print(zips)
# with open('hi.json', 'w') as json_file:
#   json.dump(zips, json_file)

# %%
file = "../geojson/ia_iowa_zip_codes_geo.min.json"

with open(file) as jsonfile:
    state_json = json.load(jsonfile)

data = state_json["features"]

ia_zips = []

for i in range(len(data)):
    if data[i]["properties"]["ZCTA5CE10"] in zipcodes:
        ia_zips.append(data[i])

# print(zips)
# with open('ia.json', 'w') as json_file:
#   json.dump(zips, json_file)

# %%
file = "../geojson/il_illinois_zip_codes_geo.min.json"

with open(file) as jsonfile:
    state_json = json.load(jsonfile)

data = state_json["features"]

il_zips = []

for i in range(len(data)):
    if data[i]["properties"]["ZCTA5CE10"] in zipcodes:
        il_zips.append(data[i])

# print(zips)
# with open('il.json', 'w') as json_file:
#   json.dump(zips, json_file)

# %%
file = "../geojson/ma_massachusetts_zip_codes_geo.min.json"

with open(file) as jsonfile:
    state_json = json.load(jsonfile)

data = state_json["features"]

ma_zips = []

for i in range(len(data)):
    if data[i]["properties"]["ZCTA5CE10"] in zipcodes:
        ma_zips.append(data[i])

print(ma_zips)
with open('ma.json', 'w') as json_file:
  json.dump(ma_zips, json_file)
# Out:
# []

# %%
file = "../geojson/md_maryland_zip_codes_geo.min.json"

with open(file) as jsonfile:
    state_json = json.load(jsonfile)

data = state_json["features"]

md_zips = []

for i in range(len(data)):
    if data[i]["properties"]["ZCTA5CE10"] in zipcodes:
        md_zips.append(data[i])

# print(zips)
# with open('md.json', 'w') as json_file:
#   json.dump(zips, json_file)

# %%
file = "../geojson/nc_north_carolina_zip_codes_geo.min.json"

with open(file) as jsonfile:
    state_json = json.load(jsonfile)

data = state_json["features"]

nc_zips = []

for i in range(len(data)):
    if data[i]["properties"]["ZCTA5CE10"] in zipcodes:
        nc_zips.append(data[i])

# print(zips)
# with open('nc.json', 'w') as json_file:
#   json.dump(zips, json_file)

# %%
file = "../geojson/nj_new_jersey_zip_codes_geo.min.json"

with open(file) as jsonfile:
    state_json = json.load(jsonfile)

data = state_json["features"]

nj_zips = []

for i in range(len(data)):
    if data[i]["properties"]["ZCTA5CE10"] in zipcodes:
        nj_zips.append(data[i])

# print(zips)
# with open('nj.json', 'w') as json_file:
#   json.dump(zips, json_file)

# %%
file = "../geojson/nm_new_mexico_zip_codes_geo.min.json"

with open(file) as jsonfile:
    state_json = json.load(jsonfile)

data = state_json["features"]

nm_zips = []

for i in range(len(data)):
    if data[i]["properties"]["ZCTA5CE10"] in zipcodes:
        nm_zips.append(data[i])

print(nm_zips)
with open('nm.json', 'w') as json_file:
  json.dump(nm_zips, json_file)
# Out:
# []

# %%
file = "../geojson/nv_nevada_zip_codes_geo.min.json"

with open(file) as jsonfile:
    state_json = json.load(jsonfile)

data = state_json["features"]

nv_zips = []

for i in range(len(data)):
    if data[i]["properties"]["ZCTA5CE10"] in zipcodes:
        nv_zips.append(data[i])

# print(zips)
# with open('ga.json', 'w') as json_file:
#   json.dump(zips, json_file)

# %%
file = "../geojson/nv_nevada_zip_codes_geo.min.json"

with open(file) as jsonfile:
    state_json = json.load(jsonfile)

data = state_json["features"]

nv_zips = []

for i in range(len(data)):
    if data[i]["properties"]["ZCTA5CE10"] in zipcodes:
        nv_zips.append(data[i])

print(zips)
with open('nv.json', 'w') as json_file:
  json.dump(nv_zips, json_file)
# Out:
# [{'type': 'Feature', 'properties': {'STATEFP10': '42', 'ZCTA5CE10': '15222', 'GEOID10': '4215222', 'CLASSFP10': 'B5', 'MTFCC10': 'G6350', 'FUNCSTAT10': 'S', 'ALAND10': 2103908, 'AWATER10': 676361, 'INTPTLAT10': '+40.4476787', 'INTPTLON10': '-079.9934618', 'PARTFLG10': 'N'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[-79.993481, 40.449749], [-79.993364, 40.44982], [-79.993248, 40.449892], [-79.992924, 40.450089], [-79.992395, 40.450413], [-79.991529, 40.451046], [-79.991317, 40.451202], [-79.990791, 40.451588], [-79.988756, 40.453078], [-79.985568, 40.455413], [-79.982655, 40.457549], [-79.980621, 40.45904], [-79.980423, 40.459248], [-79.979831, 40.459872], [-79.979634, 40.460081], [-79.97891, 40.460682], [-79.976739, 40.462489], [-79.976016, 40.463091], [-79.975861, 40.463022], [-79.975778, 40.462985], [-79.975706, 40.462954], [-79.975266, 40.46276], [-79.975064, 40.46267], [-79.974827, 40.462565], [-79.97465, 40.462487], [-79.974456, 40.462399], [-79.974223, 40.462208], [-79.
# ...

# %%
file = "../geojson/ny_new_york_zip_codes_geo.min.json"

with open(file) as jsonfile:
    state_json = json.load(jsonfile)

data = state_json["features"]

ny_zips = []

for i in range(len(data)):
    if data[i]["properties"]["ZCTA5CE10"] in zipcodes:
        ny_zips.append(data[i])

print(ny_zips)
with open('ny.json', 'w') as json_file:
  json.dump(ny_zips, json_file)
# Out:
# [{'type': 'Feature', 'properties': {'STATEFP10': '36', 'ZCTA5CE10': '10065', 'GEOID10': '3610065', 'CLASSFP10': 'B5', 'MTFCC10': 'G6350', 'FUNCSTAT10': 'S', 'ALAND10': 1000544, 'AWATER10': 0, 'INTPTLAT10': '+40.7645840', 'INTPTLON10': '-073.9630128', 'PARTFLG10': 'N'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[-73.969337, 40.763547], [-73.969619, 40.763663], [-73.970957, 40.764216], [-73.972553, 40.764898], [-73.972099, 40.765518], [-73.971648, 40.766143], [-73.971189, 40.766767], [-73.970728, 40.767394], [-73.970281, 40.768025], [-73.969825, 40.768646], [-73.969365, 40.769271], [-73.968904, 40.769901], [-73.968441, 40.770517], [-73.966847, 40.769847], [-73.965238, 40.769169], [-73.963618, 40.768487], [-73.964077, 40.76786], [-73.96247, 40.767185], [-73.961883, 40.766937], [-73.96174, 40.76712], [-73.961403, 40.767554], [-73.959777, 40.766868], [-73.959353, 40.766688], [-73.957412, 40.765868], [-73.95516, 40.764918], [-73.955616, 40.76429], [-73.95493, 40.764006], [-73.953508
# ...

# %%
file = "../geojson/or_oregon_zip_codes_geo.min.json"

with open(file) as jsonfile:
    state_json = json.load(jsonfile)

data = state_json["features"]

or_zips = []

for i in range(len(data)):
    if data[i]["properties"]["ZCTA5CE10"] in zipcodes:
        or_zips.append(data[i])

print(or_zips)
with open('or.json', 'w') as json_file:
  json.dump(or_zips, json_file)
# Out:
# []

# %%
file = "../geojson/pa_pennsylvania_zip_codes_geo.min.json"

with open(file) as jsonfile:
    state_json = json.load(jsonfile)

data = state_json["features"]

pa_zips = []

for i in range(len(data)):
    if data[i]["properties"]["ZCTA5CE10"] in zipcodes:
        pa_zips.append(data[i])

# print(zips)
# with open('pa.json', 'w') as json_file:
#   json.dump(zips, json_file)

# %%
file = "../geojson/tx_texas_zip_codes_geo.min.json"

with open(file) as jsonfile:
    state_json = json.load(jsonfile)

data = state_json["features"]

tx_zips = []

for i in range(len(data)):
    if data[i]["properties"]["ZCTA5CE10"] in zipcodes:
        tx_zips.append(data[i])

# print(zips)
# with open('tx.json', 'w') as json_file:
#   json.dump(zips, json_file)

# %%
file = "../geojson/va_virginia_zip_codes_geo.min.json"

with open(file) as jsonfile:
    state_json = json.load(jsonfile)

data = state_json["features"]

va_zips = []

for i in range(len(data)):
    if data[i]["properties"]["ZCTA5CE10"] in zipcodes:
        va_zips.append(data[i])

# print(zips)
# with open('va.json', 'w') as json_file:
#   json.dump(zips, json_file)

# %%
file = "../geojson/wa_washington_zip_codes_geo.min.json"

with open(file) as jsonfile:
    state_json = json.load(jsonfile)

data = state_json["features"]

wa_zips = []

for i in range(len(data)):
    if data[i]["properties"]["ZCTA5CE10"] in zipcodes:
        wa_zips.append(data[i])

# print(zips)
# with open('wa.json', 'w') as json_file:
#   json.dump(zips, json_file)

# %%
geojson = ak_zips + ca_zips + wa_zips + va_zips + dc_zips + nc_zips + tx_zips + il_zips + hi_zips + de_zips + ny_zips + fl_zips + pa_zips + md_zips + ia_zips + ga_zips

# %%
with open('merge.json', 'w') as json_file:
  json.dump(geojson, json_file)

# %%
print(ny_zips)
# Out:
# []

# %%
zipcodes = ['20001', '11201', '10014', '20002', '20003', '11217','94109','94086', '02139', '77008', '20010' ]
file = "../geojson/us-zip-code-latitude-and-longitude (1).csv"

topzips_df = pd.read_csv(file)
topzips_df.head()
topzips = topzips_df.Zip.isin(zipcodes)
topzip =topzips_df[topzips]
topzip.head(15)
topzips =topzip[["Zip", "Latitude", "Longitude"]]
# topzipcodes= topzips.reset_index(drop=True, inplace=True)
topzip = topzips.reset_index(drop = True)
topzip.head(15)

# topzip.to_json('zips.json', orient = 'columns', compression = 'infer', index = 'false')
# Out:
#       Zip   Latitude  Longitude
# 0   20010  38.933311  -77.02929
# 1   94086  37.378341 -122.02398
# 2    2139  42.364347  -71.10431
# 3   10014  40.734718  -74.00532
# 4   20001  38.907711  -77.01732
# 5   20003  38.881762  -76.99447
# 6   20002  38.901811  -76.99097
# 7   11217  40.682090  -73.97783
# 8   11201  40.695286  -73.98907
# 9   94109  37.792778 -122.42188
# 10  77008  29.798777  -95.40951
